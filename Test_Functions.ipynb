# %% [markdown]
# ## Imports

# %%
import cheetah
from functions import *

# %% [markdown]
# ## Convert ParticleGroup to Cheetah Objects: ParameterBeam and ParticleBeam

# %%
PFILE_cheetah = 'YAG03_impact_to_astra.h5'
test_ParameterBeam = cheetah.ParameterBeam.from_astra(PFILE_cheetah)
test_ParticleBeam = cheetah.ParticleBeam.from_astra(PFILE_cheetah)

# %% [markdown]
# ## Convert Cheetah Objects to ParticleGroup

# %%
ParticleGroup1 = ParameterBeam_to_ParticleGroup(2e5,test_ParameterBeam)
ParticleGroup2 = ParticleBeam_to_ParticleGroup(test_ParticleBeam)
# Out:
# /sdf/home/c/cropp/Cheetah2OpenPMD/functions.py:132: RuntimeWarning: divide by zero encountered in divide
#   't': dist['z']/(beta_z*c),
# /sdf/home/c/cropp/Cheetah2OpenPMD/functions.py:132: RuntimeWarning: invalid value encountered in divide
#   't': dist['z']/(beta_z*c),

# %% [markdown]
# ## Compare plots

# %%
ParticleGroup1.plot('x','y')

# %%
ParticleGroup2.plot('x','y')

# %% [markdown]
# ## Compare beam matrices

# %%
ParticleGroup1.cov('x','px','y','py','z','kinetic_energy')
# Out:
# array([[ 5.79630472e-08,  1.03329320e+00,  7.93032683e-11,
#          5.94637479e-02,  3.78418306e-10, -2.71255927e-02],
#        [ 1.03329320e+00,  1.92193298e+07, -5.70122374e-02,
#          1.83753648e+04,  7.38819753e-03, -5.92782370e+05],
#        [ 7.93032683e-11, -5.70122374e-02,  5.81947247e-08,
#          1.03694108e+00, -3.04856207e-10,  2.54335724e-02],
#        [ 5.94637479e-02,  1.83753648e+04,  1.03694108e+00,
#          1.92780718e+07, -3.22139156e-03,  3.00291039e+05],
#        [ 3.78418306e-10,  7.38819753e-03, -3.04856207e-10,
#         -3.22139156e-03,  3.43788425e-07, -1.71160744e+01],
#        [-2.71255927e-02, -5.92782370e+05,  2.54335724e-02,
#          3.00291039e+05, -1.71160744e+01,  1.94996522e+09]])

# %%
ParticleGroup2.cov('x','px','y','py','z','kinetic_energy')
# Out:
# array([[ 5.79616139e-08,  1.03294207e+00,  9.11022295e-12,
#          5.82429139e-02,  2.23853658e-12, -2.50265398e-04],
#        [ 1.03294207e+00,  1.92072727e+07, -5.78476877e-02,
#          4.77267787e+03,  3.24841433e-06, -3.10258312e+03],
#        [ 9.11022295e-12, -5.78476877e-02,  5.81320789e-08,
#          1.03598007e+00,  6.26132289e-12,  4.59621886e-04],
#        [ 5.82429139e-02,  4.77267787e+03,  1.03598007e+00,
#          1.92637667e+07,  4.48560903e-05,  1.18053529e+04],
#        [ 2.23853658e-12,  3.24841433e-06,  6.26132289e-12,
#          4.48560903e-05,  3.43789038e-07, -1.71309260e+01],
#        [-2.50265398e-04, -3.10258312e+03,  4.59621886e-04,
#          1.18053529e+04, -1.71309260e+01,  1.95143747e+09]])

# %% [markdown]
# ## Compare Twiss

# %%
ParticleGroup1.twiss("x")
# Out:
# {'alpha_x': -4.801282443873436,
#  'beta_x': 17.20023049925663,
#  'gamma_x': 1.3983715571071438,
#  'emit_x': 3.3698775053277967e-09,
#  'eta_x': -0.0008883563487531449,
#  'etap_x': -0.00030398665434646743,
#  'norm_emit_x': 4.2115585484252444e-07}

# %%
ParticleGroup2.twiss("x")
# Out:
# {'alpha_x': -4.799700634103328,
#  'beta_x': 17.199958544199607,
#  'gamma_x': 1.3975107041823656,
#  'emit_x': 3.369869392864961e-09,
#  'eta_x': -8.147508040821724e-06,
#  'etap_x': -1.5796748271626946e-06,
#  'norm_emit_x': 4.211548520858126e-07}
